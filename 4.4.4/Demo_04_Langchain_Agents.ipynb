# %% [markdown]
# # **LangChain Agents**
#
# ### **Objective:**
# To understand how to create, configure, and use **LangChain Agents**. This demo demonstrates initializing an agent, loading tools, and using the agent to perform actions such as mathematical calculations, web searches, and retrieving information from Wikipedia.
#
# ---
#
# ### **Note:**
# - Before running any demo, ensure that the **requirements.txt** file is installed. This file contains all the required dependencies for **all demos and guided practices under Building LLM Applications**.
# - If the dependencies were already installed earlier (after creating the virtual environment), there is no need to install them again. You can directly proceed with running the demo.
# - Refer to Lesson_01 **Demo_01_Zero_Shot_Prompting.ipynb** Step 1 for creating a virtual environment and installing the requirements.txt
# - Ensure you select the right kernel **Python (myenv)** while running the demos.
# - You will need a valid **SerpAPI key** for live Google search queries.
# ---
#
# ### **Steps to perform:**
# 1. Import the necessary modules
# 2. Initialize the chat model
# 3. Load the tools
# 4. Initialize the agent
# 5. Use the agent to ask questions
# 6. Use the agent to ask another question
#
# ---

# %% [markdown]
# ### **Step 1: Import the necessary modules**
# - Import essential LangChain modules for tools, agents, and chat models

# %%
from langchain_openai import ChatOpenAI
from langchain_community.utilities import WikipediaAPIWrapper, SerpAPIWrapper
from langchain_community.tools import WikipediaQueryRun
from langchain_experimental.tools.python.tool import PythonREPLTool
from langchain_core.tools import tool
from langchain.agents import create_agent
from typing import List

# %% [markdown]
# # **Step 2: Initialize the chat model**
#
# - Initialize the ChatOpenAI model, which serves as the reasoning engine behind the agent

# %%
llm = ChatOpenAI(model="gpt-5-mini")

# %%
serpapi_key = "93066f5581a12839e7ba8b60605c78fa739ccdd1caf99d3f03a956788a338b70"  # ADD YOUR SERPAPI KEY HERE

# %% [markdown]
# # **Step 3: Load the tools**
#
#
# - Define tools that the agent can use for external data access or computations.
#
# - The tools include:
#   - SerpAPI Search Tool for live Google searches
#   - Wikipedia Tool for encyclopedia lookups
#   - Math REPL Tool for executing Python expressions and math operations

# %%
@tool
def search_tool(query: str) -> str:
    """Search Google for current information using SerpAPI."""
    return SerpAPIWrapper(serpapi_api_key=serpapi_key).run(query)

@tool
def wikipedia_tool(query: str) -> str:
    """Search Wikipedia for detailed information."""
    wiki_api = WikipediaAPIWrapper()
    return WikipediaQueryRun(api_wrapper=wiki_api).run(query)

@tool
def math_tool(expression: str) -> str:
    """Execute math operations and Python expressions (replaces llm-math)."""
    return PythonREPLTool().run(expression)

# %%
tools = [search_tool, wikipedia_tool, math_tool]
print("✅ Tools loaded: SerpAPI Search, Wikipedia, Math REPL")
# Out:
# ✅ Tools loaded: SerpAPI Search, Wikipedia, Math REPL

# %% [markdown]
# - These tools enable the agent to extend beyond language reasoning and access real-time data or perform computations.

# %% [markdown]
# ### **Step 4: Initialize the agent**
# - Combine the loaded tools and chat model into a unified LangChain agent

# %%
agent_executor = create_agent(llm, tools)

# %%
def ask_agent(question: str) -> str:
    """Ask the agent a question and return the final answer."""
    result = agent_executor.invoke({"messages": [("human", question)]})
    return result["messages"][-1].content

# %% [markdown]
# - The create_agent() function wraps tools and the model together, enabling autonomous reasoning and execution.

# %% [markdown]
# ### **Step 5: Use tge agent to ask questions**
# - Use the agent to solve problems or answer factual queries

# %%
ask_agent("What is the square root of 16?")
# Out:
# 'The principal square root of 16 is 4, since 4^2 = 16. (Both ±4 are square roots of 16, i.e., 4 and -4.)'

# %% [markdown]
# ### **Step 6: Use agent to ask another question**
# - Ask an open-ended question that requires retrieving information from Wikipedia

# %%
ask_agent("Alan Turing was a British mathematician and computer scientist, what is he famous for?")
# Out:
# 'Alan Turing (1912–1954) is famous for several foundational contributions to mathematics, computing, cryptography and early artificial intelligence:\n\n- The Turing machine (1936): a theoretical model of computation Turing introduced to formalize the idea of an algorithm. It established the modern foundations of computer science and computability theory.\n- Cracking Enigma in WWII: at Bletchley Park he helped develop techniques and electromechanical machines (including work that led to the Bombe) that significantly broke German encryption and aided the Allied war effort.\n- The Turing test (1950): in his paper "Computing Machinery and Intelligence" he proposed a behavioral test for machine intelligence that has shaped debates about AI ever since.\n- Early design of electronic computers: he contributed designs and ideas for practical stored-program computers (e.g., the Automatic Computing Engine, ACE).\n- Work on mathematical biology: late in life he published influential work on morphogenesis (how patterns form in nature).\n- Personal and cultural legacy: prosecuted in 1952 for homosexual acts, chemically castrated, and died in 1954; he later received official apologies and a posthumous pardon, and is widely celebrated as the “father of computer science.”\n\nIf you want, I can expand on any of these points (how a Turing machine works, details of the Enigma work, the Turing test, or his biography).'

# %% [markdown]
# - Additional Example Questions

# %%
# Additional Questions to ask the agent
ask_agent("what was the price of gold yesterday in the US")
# Out:
# 'Do you mean the spot price or the COMEX futures settlement/closing price?\n\nQuick answer (most commonly used): the COMEX futures settlement for Feb 23, 2026 was $5,204.70 per troy ounce. Spot prices varied intraday (reports around Feb 23 show spot trading roughly between ~$5,150 and ~$5,232/oz). \n\nTell me which exact price you want (spot at NY close, COMEX settlement, or a specific source) and I’ll pull the precise number.'

# %%
ask_agent("Who is the current president of USA")
# Out:
# 'As of today (February 24, 2026), the President of the United States is Donald J. Trump. He was inaugurated on January 20, 2025.'

# %%
ask_agent("What was the price of bitcoin on 31st December 2020?")
# Out:
# 'On 31 December 2020 Bitcoin closed at about $29,001.72 (USD) — commonly reported as ≈ $29,000. Sources (e.g., Yahoo Finance historical BTC‑USD) show a high that day around $29,244.88 and a low near $28,201.99. \n\nIf you want the price on a specific exchange, the exact timestamp, or the open/high/low/close numbers for that day, tell me which and I’ll pull them.'

# %%
ask_agent("What was the price of bitcoin yesterday")
# Out:
# 'Do you mean the Bitcoin (BTC) price yesterday in US dollars? And do you want the closing price for Feb 23, 2026 (UTC) or a spot/average price from a particular exchange?'

# %%
ask_agent("Can you justify the fluctuation in price of bitcoin")
# Out:
# 'Short answer: Bitcoin’s price fluctuates because supply/demand in a thin, 24/7, globally traded market is highly sensitive to news, leverage, and shifts in investor sentiment — and because its fundamental supply mechanics and market structure amplify moves. Those forces, acting together, create much larger and faster swings than in most traditional assets.\n\nKey reasons (concise):\n\n- Supply-demand imbalance and concentrated supply\n  - Large holders (“whales”) and miners control big portions of available BTC; their buying or selling moves price more than similar-sized trades in deep equity markets.\n  - New supply is predictable (block rewards, halving events), but most trading happens on the margin; small changes in demand can have outsized price effects.\n\n- Market structure and liquidity\n  - Crypto markets are open 24/7 with many fragmented venues. Order-book depth can be thin at key price levels, so relatively small orders create big moves.\n  - Liquidity varies by exchange, time zone, and asset pair.\n\n- Leverage and derivatives\n  - Futures, perpetual swaps, and margin amplify moves. Forced liquidations (when leveraged positions close) can cascade into sharp price moves (both up and down).\n  - Funding rates, open interest and basis swings cause rapid flows between spot and derivatives markets.\n\n- News, regulation, and events\n  - Regulatory announcements, exchange outages/hacks, corporate purchases/sales, ETF approvals, or macro headlines produce immediate re-pricing of risk.\n  - Examples: 2017 ICO/speculative boom and 2018 unwind; pandemic shock in March 2020; selling around major exchange failures; US spot-ETF filings/approvals and the 2024 halving both materially affected prices.\n\n- Macro and liquidity environment\n  - Changes in interest rates, dollar strength, and risk-on/risk-off sentiment influence flows into speculative assets like bitcoin.\n\n- Network fundamentals and ecosystem signals\n  - On-chain indicators (active addresses, fees, miner behavior) change perceived utility and holder conviction.\n  - Protocol events (halvings, upgrades) change future supply expectations and miner economics.\n\n- Behavioral and sentiment drivers\n  - Retail-driven FOMO and panic selling, social-media amplification, and narrative shifts (store of value vs. payments vs. speculation) produce herd effects.\n\nHow to “justify” or analyze a particular fluctuation\n- Look at a short window and check:\n  - Exchange order books and trade volume (was liquidity thin?)\n  - Exchange inflows/outflows and large wallet transfers (were whales/misplaced funds moving?)\n  - Funding rates and open interest (were leveraged positions crowded?)\n  - News/regulatory releases and social sentiment spikes (was there a catalyst?)\n  - On-chain metrics (exchange balance changes, active addresses, SOPR, realized cap)\n  - Broader markets (equity moves, USD index, rates)\n- Quantitative attribution: regress returns on these factors (funding, inflows, volume, macro variables) to assign weights to causes.\n\nPractical notes\n- Expect higher volatility than stocks or bonds; that’s an inherent feature of an emerging, concentrated, speculative asset.\n- To manage exposure: diversify, use position sizing, reduce leverage, or hedge with options/futures.\n\nIf you want, I can:\n- Analyze a specific price swing (give me the date/time range) and run the attribution checks above.\n- Build a checklist or dashboard of the key indicators to monitor for future moves.'

# %% [markdown]
# - These queries combine Wikipedia and SerpAPI tools, demonstrating the agent’s capability to fetch and reason over both static and real-time data sources.

# %% [markdown]
# ### __Conclusion__
#
# By following these steps, you learned how to create and utilize a LangChain Agent capable of reasoning, searching, and performing calculations. You integrated tools like SerpAPI, Wikipedia, and Math REPL into the agent, allowing it to handle both factual and computational queries.
#
# LangChain Agents are powerful for building autonomous, multi-tool AI systems that can interpret, search, calculate, and provide comprehensive, context-aware answers.
#
# ---
