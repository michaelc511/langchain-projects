# %% [markdown]
# # **Building a Conversational Chatbot**
#
# ### **Objective:**
# To design and implement an interactive **Conversational Chatbot** using **LangChain** and **OpenAI’s GPT-5-mini**.
# This guided practice demonstrates how to load data, split documents, generate embeddings, create a retriever, and connect it all into a functional chatbot system.
#
# ---
# ### **Note:**
# - Before running any demo, ensure that the **requirements.txt** file is installed. This file contains all the required dependencies for **all demos and guided practices under Building LLM Applications**.
# - If the dependencies were already installed earlier (after creating the virtual environment), there is no need to install them again. You can directly proceed with running the demo.
# - Refer to Lesson_01 **Demo_01_Zero_Shot_Prompting.ipynb** Step 1 for creating a virtual environment and installing the requirements.txt
# - Ensure you select the right kernel **Python (myenv)** while running the demos
# ---
#
#
# ### **Steps to perform:**
# 1. Set up the environment
# 2. Define a document loader
# 3. Create a document splitter
# 4. Embed the text and save it in vector stores
# 5. Create a retrieval function
# 6. Run the chatbot and understand the code
#
# ---

# %% [markdown]
# ### **Step 1: Set up the environment**
#
#
# *   Import the necessary libraries

# %%
import os
import time
import langchain_classic  # enable backwards compatibility

from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain_classic.chains import RetrievalQA

# %% [markdown]
# ### **Step 2: Define a document loader**
#
# - Use a document loader like PyPDF to load information from a PDF file

# %%
loader = PyPDFLoader("bcg-2022-annual-sustainability-report-apr-2023.pdf")
documents = loader.load()

# %% [markdown]
# ### **Step 3: Create a document splitter**
#
#
# *   Break down big pieces of text into smaller parts using text splitters

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=150,
    chunk_overlap=0,
    separators=["\n\n", "\n", "(?<=\. )", " ", ""]
)

chunks = splitter.split_documents(documents)

# %% [markdown]
# ### **Step 4: Embed the text and save it in vector stores**
#
#
# *  Arrange a place to store and organize the text splits to make them searchable
# *  Employ OpenAIEmbeddings to create a pretrained model instance, saving the results in a specified directory path

# %%
embeddings = OpenAIEmbeddings()

# %%
vectorstore = FAISS.from_documents(chunks, embeddings)
retriever = vectorstore.as_retriever()

# %% [markdown]
# ### **Step 5: Create a retrieval function**
#
# - Retrieve pertinent data from storage based on user input using a retriever

# %%
llm = ChatOpenAI(model_name="gpt-5-mini")

# %%
qa = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    return_source_documents=True
)

# %% [markdown]
# ### **Step 6: Run the chatbot and understand the code**
#
# - Set up the chatbot, run it and interact with it

# %%
while True:
    query = input("\nEnter a query: ")
    
    if query == "exit":
        break
    if query.strip() == "":
        continue

    start = time.time()
    
    # NEW: Updated to modern LangChain API
    res = qa.invoke(query)
    
    end = time.time()

    print("\n\n> Question:")
    print(query)

    print(f"\n> Answer (took {round(end - start, 2)}s):")
    print(res["result"])
# Out:
# Enter a query:  What is quantum reality?
# > Question:
# What is quantum reality?
#
# > Answer (took 27.08s):
# "Quantum reality" refers to what the world is like according to quantum mechanics — not just the equations and predictions, but what those equations imply about the nature of physical things (particles, fields, measurement outcomes, space, causation, etc.). Physicists agree on how to use quantum theory to make predictions, but they disagree about what the theory says is actually happening “behind the scenes.” That disagreement is the core of questions about quantum reality.
#
# Key concepts you’ll hear in this discussion
# - Superposition: a quantum system can be in a combination of different possible states at once (until something forces one outcome).
# - Wavefunction (or quantum state): the mathematical object that encodes probabilities for measurement outcomes. Whether the wavefunction is a real physical object (ontic) or just a tool for our knowledge (epistemic) is contested.
# - Measurement problem / collapse: when and how a superposition becomes a definite observed outcome is not fully settled by the standard formalism.
# - Entanglement: parts of a system can have correlations stronger than classically possible; measuring one part can affect the description of another even when separated.
# - Nonlocality and Bell’s theorem: experiments violating Bell inequalities rule out local hidden-variable explanations — nature cannot be both local (in a particular technical sense) and obey certain classical intuitions about preexisting values.
# - Decoherence and emergence of classicality: interaction with the environment suppresses interference between components of a superposition, explaining why macroscopic objects look classical, though decoherence by itself doesn’t solve all conceptual issues about outcomes.
#
# Main families of interpretations (brief)
# - Copenhagen-type (instrumentalist): Quantum mechanics is a tool for predicting measurement results. Reality is described operationally; talk of underlying processes is kept minimal.
# - Many-Worlds / Everett: The wavefunction never collapses. All possible outcomes occur in branching, non-communicating branches of the universe; apparent randomness is due to branch selection.
# - Pilot-wave / de Broglie–Bohm: Particles have definite positions guided deterministically by a real wavefunction. This is explicitly nonlocal.
# - Objective-collapse theories (e.g., GRW): The wavefunction is real and occasionally collapses spontaneously; collapse is a physical process that produces definite outcomes.
# - QBism (quantum Bayesianism): The quantum state represents an agent’s personal degrees of belief about future experiences; quantum probabilities are subjective.
# - Relational quantum mechanics: Properties are relative to other systems; there is no absolute state independent of interactions.
#
# What experiments have taught us
# - Quantum theory’s predictions (superposition, interference, entanglement) are extraordinarily well confirmed.
# - Violation of Bell inequalities rules out local hidden-variable theories.
# - Decoherence experiments show how classical behavior emerges from quantum interactions.
#
# Why there’s no single accepted answer
# - The mathematical formalism is clear and extremely successful, but translating it into a unique ontology (what exists and how it behaves) requires extra assumptions that aren’t decided by experiment so far.
# - Different interpretations make the same experimental predictions in most regimes, so choice among them often involves considerations of simplicity, metaphysics, or proposed modifications that could be testable.
#
# If you want
# - I can explain any of the major interpretations in more detail.
# - I can summarize key experiments (double-slit, Bell tests, decoherence experiments) that illuminate aspects of quantum reality.
# - I can recommend accessible books or papers depending on whether you want a philosophical or technical treatment.
# Enter a query:  exit

# %% [markdown]
# ### **Conclusion:**
# By following these steps, you have successfully built a conversational chatbot using LangChain and OpenAI’s GPT-5-mini. The chatbot retrieves context from uploaded documents, processes user queries intelligently, and provides relevant answers, demonstrating the core principles of retrieval-augmented generation (RAG) in conversational AI.
#
# ---
